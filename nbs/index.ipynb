# %% [markdown]
# ## How to use

# %% [markdown]
# The `%%dbt` cell magic allows you to create models and analyses in your dbt project.

# %%
# hide
# notest
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# To use the `%%dbt` cellmagic in your notebook, you have to load the dbt cellmagic module first via `%load_ext` or `%reload_ext` line magics

# %%
# load dbt cell magic
# %reload_ext nbdbt.dbt_cellmagic

# %%
# hide
# delete my_third_model (if existing)
! rm -f ../my_dbt_project/models/my_third_model.sql
! rm -f ../my_dbt_project/target/compiled/my_dbt_project/models/my_third_model.sql

# %% [markdown]
# The `%dbtconfig` line magic configures a default project (and optionally the dbt profiles directory with `-d` flag as well as the notebook path with the `-n` flag).

# %%
# %dbtconfig -p ../my_dbt_project -n notebooks/index.ipynb

# %% [markdown]
# The next cell uses the `%%dbt` cell magic which will create a new model `my_third_model` and compile it as well.

# %%
# %%dbt -s models/my_third_model.sql
# select *
# from {{ ref('my_second_dbt_model') }}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('dbt', 'models/my_third_model.sql', "select *\nfrom {{ ref('my_second_dbt_model') }}\n")
#
# File ~/repos/dbt_ext/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2542, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2540 with self.builtin_trap:
#    2541     args = (magic_arg_s, cell)
# -> 2542     result = fn(*args, **kwargs)
#    2544 # The code below prevents the output from being displayed
#    2545 # when using magics with decorator @output_can_be_silenced
#    2546 # when the last Python token in the expression is a ';'.
#    2547 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/repos/dbt_ext/.venv/src/nbdbt/nbdbt/dbt_cellmagic.py:449, in write_dbt(line, cell)
#     447     IPython.get_ipython().push({line_args.assign: dmo})
#     448     return None
# --> 449 results = dmo.ref()
#     450 return results
#
# AttributeError: 'DbtMagicObject' object has no attribute 'ref'

# %%
my_third_model.compiled_sql
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 my_third_model.compiled_sql
#
# AttributeError: 'DbtMagicObject' object has no attribute 'compiled_sql'

# %%
# !dbt run -s +my_third_model --project-dir ../my_dbt_project/
# Out:
# 22:29:02  Running with dbt=1.9.3
# 22:29:03  Registered adapter: snowflake=1.9.2
# 22:29:03  Found 3 models, 4 data tests, 1 source, 474 macros
# 22:29:03
# 22:29:03  Concurrency: 2 threads (target='dev')
# 22:29:03
# 22:29:04  1 of 3 START sql table model dbt_mwinkler_jaffle.my_first_dbt_model ............ [RUN]
# 22:29:05  1 of 3 OK created sql table model dbt_mwinkler_jaffle.my_first_dbt_model ....... [SUCCESS 1 in 0.82s]
# 22:29:05  2 of 3 START sql view model dbt_mwinkler_jaffle.my_second_dbt_model ............ [RUN]
# 22:29:06  2 of 3 OK created sql view model dbt_mwinkler_jaffle.my_second_dbt_model ....... [SUCCESS 1 in 0.59s]
# 22:29:06  3 of 3 START sql view model dbt_mwinkler_jaffle.my_third_model ................. [RUN]
# 22:29:06  3 of 3 OK created sql view model dbt_mwinkler_jaffle.my_third_model ............ [SUCCESS 1 in 0.28s]
# 22:29:06
# 22:29:06  Finished running 1 table model, 2 view models in 0 hours 0 minutes and 2.92 seconds (2.92s).
# 22:29:06
# 22:29:06  Completed successfully
# 22:29:06
# 22:29:06  Done. PASS=3 WARN=0 ERROR=0 SKIP=0 TOTAL=3

# %% [markdown]
# We then assigned the result of the compilation to the `my_third_model` variable, which is a Dbt (cell) magic object

# %%
# skip_test
# !dbt show -s my_third_model --project-dir ../my_dbt_project/
# Out:
# 22:26:56  Running with dbt=1.9.3
# 22:26:56  Registered adapter: snowflake=1.9.2
# 22:26:56  Found 3 models, 4 data tests, 1 source, 474 macros
# 22:26:56
# 22:26:56  Concurrency: 2 threads (target='dev')
# 22:26:56
# Previewing node 'my_third_model':
# | ID |
# | -- |
# |  1 |

# %%
# hide
# skip_test
from pathlib import Path

assert Path("../my_dbt_project/models/my_fourth_model.sql").exists()
assert Path(
    "../my_dbt_project/target/compiled/my_dbt_project/models/my_fourth_model.sql"
).exists()

# %% [markdown]
# The `ref` method on `DbtMagicObject`  allows us to run the query and save the results into a dataframe.

# %%
# skip_test
results = my_fourth_model.ref()
results  # dataframe
# Out:
#    id
# 0   1

# %% [markdown]
# The dbt magic object also has access to other useful properties (like the compiled sql used to create the results)

# %%
# skip_test
print(my_fourth_model._compiled_sql)
# Out:
# -- AUTOGENERATED! DO NOT EDIT! File to edit: notebooks/index.ipynb (unless otherwise specified).
# select *
# from `sample-dbt-learn-project`.`jaffle_shop`.`my_second_dbt_model`

# %% [markdown]
# We can then run the usual _dbt_ commands to generate the model

# %%
# no_test
# %cd ../my_dbt_project
! dbt run --select my_fourth_model
# %cd ../nbs
# Out:
# /home/butch2/play/experiments/nbdbt/nbs
# 10:20:23  Running with dbt=1.1.1
# 10:20:23  Found 3 models, 4 tests, 0 snapshots, 3 analyses, 191 macros, 0 operations, 0 seed files, 0 sources, 0 exposures, 0 metrics
# 10:20:23
# 10:20:25  Concurrency: 1 threads (target='dev')
# 10:20:25
# 10:20:25  1 of 1 START view model jaffle_shop.my_fourth_model ............................ [RUN]
# 10:20:26  1 of 1 OK created view model jaffle_shop.my_fourth_model ....................... [OK in 1.28s]
# 10:20:26
# 10:20:26  Finished running 1 view model in 2.97s.
# 10:20:26
# 10:20:26  Completed successfully
# 10:20:26
# 10:20:26  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
# /home/butch2/play/experiments/nbdbt/nbs

# %%
# skip_test
import nbdbt.dbt_cellmagic as nbc

nbc.clear_cache()  # clears nbdtcache
